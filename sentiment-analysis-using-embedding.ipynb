# %%
docs = ['go india',
		'india india',
		'hip hip hurray',
		'jeetega bhai jeetega india jeetega',
		'bharat mata ki jai',
		'kohli kohli',
		'sachin sachin',
		'dhoni dhoni',
		'modi ji ki jai',
		'inquilab zindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
# Out:
# C:\Users\munna\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
tokenizer.fit_on_texts(docs)

# %%
tokenizer.word_index
# Out:
# {'india': 1,
#  'jeetega': 2,
#  'hip': 3,
#  'ki': 4,
#  'jai': 5,
#  'kohli': 6,
#  'sachin': 7,
#  'dhoni': 8,
#  'go': 9,
#  'hurray': 10,
#  'bhai': 11,
#  'bharat': 12,
#  'mata': 13,
#  'modi': 14,
#  'ji': 15,
#  'inquilab': 16,
#  'zindabad': 17}

# %%
print(len(tokenizer.word_index))
# Out:
# 17

# %%
sequences = tokenizer.texts_to_sequences(docs)

sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
from keras.utils import pad_sequences

sequences = pad_sequences(sequences,padding='post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
import tensorflow
from keras import Sequential
from keras.layers import Embedding

model = Sequential()

# we have to add an 'embedding' layer with 17 unique words(vocabulary) in it 
model.add(Embedding(17, output_dim=2))

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)              │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam', 'accuracy')

# %%
pred = model.predict(sequences)

print(pred)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pred = model.predict(sequences)
#       3 print(pred)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# InvalidArgumentError: Graph execution error:
#
# Detected at node sequential_1/embedding_1/GatherV2 defined at (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#
#   File "<frozen runpy>", line 88, in _run_code
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 18, in <module>
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 758, in start
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 211, in start
#
#   File "C:\Users\munna\anaconda3\Lib\asyncio\base_events.py", line 683, in run_forever
#
#   File "C:\Users\munna\anaconda3\Lib\asyncio\base_events.py", line 2042, in _run_once
#
#   File "C:\Users\munna\anaconda3\Lib\asyncio\events.py", line 89, in _run
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 614, in shell_main
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_shell
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 366, in execute_request
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 827, in execute_request
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 458, in do_execute
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 663, in run_cell
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3116, in run_cell
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3171, in _run_cell
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 128, in _pseudo_sync_runner
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3394, in run_cell_async
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3639, in run_ast_nodes
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3699, in run_code
#
#   File "C:\Users\munna\AppData\Local\Temp\ipykernel_3560\618277765.py", line 1, in <module>
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 588, in predict
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 282, in one_step_on_data_distributed
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 125, in wrapper
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 271, in one_step_on_data
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py", line 110, in predict_step
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\layers\layer.py", line 953, in __call__
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\models\sequential.py", line 220, in call
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\models\functional.py", line 183, in call
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\ops\function.py", line 206, in _run_through_graph
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\models\functional.py", line 647, in call
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\layers\layer.py", line 953, in __call__
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py", line 117, in error_handler
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\ops\operation.py", line 59, in __call__
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py", line 156, in error_handler
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\layers\core\embedding.py", line 166, in call
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\ops\numpy.py", line 6275, in take
#
#   File "C:\Users\munna\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\numpy.py", line 2619, in take
#
# indices[9,1] = 17 is not in [0, 17)
# 	 [[{{node sequential_1/embedding_1/GatherV2}}]] [Op:__inference_one_step_on_data_distributed_161]
